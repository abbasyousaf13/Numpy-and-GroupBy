# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
df.loc[1, "cast"].split(", ")
# Out:
# ['Ama Qamata',
#  'Khosi Ngema',
#  'Gail Mabalane',
#  'Thabang Molaba',
#  'Dillon Windvogel',
#  'Natasha Thahane',
#  'Arno Greeff',
#  'Xolile Tshabalala',
#  'Getmore Sithole',
#  'Cindy Mahlangu',
#  'Ryle De Morny',
#  'Greteli Fincham',
#  'Sello Maake Ka-Ncube',
#  'Odwa Gwanya',
#  'Mekaila Mathys',
#  'Sandi Schultz',
#  'Duane Williams',
#  'Shamilla Miller',
#  'Patrick Mofokeng']

# %%
arr = df.loc[1, "cast"].split(", ")
len(arr)
# Out:
# 19

# %%
df.loc[df["title"] == "Kota Factory"]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
df.loc[df["title"] != "Kota Factory"]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#One Hot Encoding
df["cast"] = df["cast"].replace(np.nan, "None")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.loc[df.release_year > 2020].count()
# Out:
# show_id         592
# type            592
# title           592
# director        297
# cast            592
# country         383
# date_added      592
# release_year    592
# rating          592
# duration        592
# listed_in       592
# description     592
# dtype: int64

# %% [markdown]
# ## GroupBy

# %%
df.groupby("type")["rating"].value_counts()
# Out:
# type     rating
# Movie    TV-MA       2062
#          TV-14       1427
#          R            797
#          TV-PG        540
#          PG-13        490
#          PG           287
#          TV-Y7        139
#          TV-Y         131
#          TV-G         126
#          NR            75
#          G             41
#          TV-Y7-FV       5
#          NC-17          3
#          UR             3
#          66 min         1
#          74 min         1
#          84 min         1
# TV Show  TV-MA       1145
#          TV-14        733
#          TV-PG        323
#          TV-Y7        195
#          TV-Y         176
#          TV-G          94
#          NR             5
#          R              2
#          TV-Y7-FV       1
# Name: rating, dtype: int64

# %%
df.groupby("type")["rating", "country"].count()
# Out:
# C:\Users\Abbas\AppData\Local\Temp/ipykernel_6248/2845526892.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("type")["rating", "country"].count()
#          rating  country
# type
# Movie      6129     5691
# TV Show    2674     2285

# %%
df.groupby("type").groups
# Out:
# {'Movie': [0, 6, 7, 9, 12, 13, 16, 18, 22, 23, 24, 26, 27, 28, 29, 30, 35, 36, 38, 41, 42, 43, 44, 45, 46, 48, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 68, 71, 73, 75, 77, 78, 79, 80, 81, 84, 86, 88, 90, 91, 93, 94, 96, 101, 103, 105, 107, 112, 113, 114, 115, 116, 117, 118, 119, 122, 126, 127, 128, 129, 130, 131, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 149, 150, 151, 152, 155, 156, 157, 158, 159, 161, 162, ...], 'TV Show': [1, 2, 3, 4, 5, 8, 10, 11, 14, 15, 17, 19, 20, 21, 25, 31, 32, 33, 34, 37, 39, 40, 47, 49, 50, 55, 65, 66, 67, 69, 70, 72, 74, 76, 82, 83, 85, 87, 89, 92, 95, 97, 98, 99, 100, 102, 104, 106, 108, 109, 110, 111, 120, 121, 123, 124, 125, 132, 147, 148, 153, 154, 160, 165, 181, 184, 186, 187, 189, 193, 194, 197, 198, 212, 213, 218, 219, 220, 222, 223, 224, 225, 226, 232, 234, 241, 242, 243, 245, 248, 254, 260, 263, 265, 266, 269, 271, 272, 273, 274, ...]}

# %%
df.groupby(["type","country"]).count()
# Out:
#                                                             show_id  title  \
# type    country
# Movie   , France, Algeria                                         1      1
#         Argentina                                                38     38
#         Argentina, Brazil, France, Poland, Germany, Den...        1      1
#         Argentina, Chile                                          2      2
#         Argentina, Chile, Peru                                    1      1
# ...                                                             ...    ...
# TV Show United States, South Korea, China                         2      2
#         United States, Sweden                                     1      1
#         United States, United Kingdom                             9      9
#         United States, United Kingdom, Australia                  1      1
#         Uruguay, Germany                                          1      1
#
# ...
